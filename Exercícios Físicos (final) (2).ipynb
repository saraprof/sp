# %% [markdown]
# # Personal Training
# ## PT
# ### PT
# #### PT

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Vq7qvUj6CXs')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('EgNqVhM2lno')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('dYZWgcqxGvo')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('74G6kn0vjPQ')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('grvikOqi-_c')

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('KZGH46pP_uY')
